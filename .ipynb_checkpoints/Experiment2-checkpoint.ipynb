# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salaries.csv')
# Out:
# /home/jalaj/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year
# count  148654.000000  148654.000000     148654.000000  148654.000000
# mean    74327.500000   74768.321972      93692.554811    2012.522643
# std     42912.857795   50517.005274      62793.533483       1.117538
# min         1.000000    -618.130000       -618.130000    2011.000000
# 25%     37164.250000   36168.995000      44065.650000    2012.000000
# 50%     74327.500000   71426.610000      92404.090000    2013.000000
# 75%    111490.750000  105839.135000     132876.450000    2014.000000
# max    148654.000000  567595.430000     567595.430000    2014.000000

# %%
#BasePay, OtherPay, OvertimePay and Benefits should be numeric values but due to the presence of the value "Not Provided" these feilds are not recognised as numeric but rather as string/text feilds

# %%
#dropping rows with values as "Not Provided"
df = df[df.Benefits != "Not Provided"]
df = df[df.TotalPay != "Not Provided"]
# Out:
# /home/jalaj/.local/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
#converting these feilds to numeric
df.BasePay = pd.to_numeric(df.BasePay)
df.OtherPay = pd.to_numeric(df.OtherPay)
df.OvertimePay = pd.to_numeric(df.OvertimePay)
df.Benefits = pd.to_numeric(df.Benefits)

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148650.000000  148045.000000  148650.000000  148650.000000
# mean    74325.500047   66325.448840    5066.059886    3648.767297
# std     42911.703176   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37163.250000   33588.200000       0.000000       0.000000
# 50%     74325.500000   65007.450000       0.000000     811.270000
# 75%    111487.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year
# count  148650.000000  148650.000000     148650.000000  148650.000000
# mean    20906.772746   74770.333901      93695.075969    2012.522603
# std     16955.512494   50516.196009      62792.497391       1.117526
# min       -33.890000    -618.130000       -618.130000    2011.000000
# 25%      1864.000000   36169.955000      44073.337500    2012.000000
# 50%     25101.310000   71427.240000      92406.020000    2013.000000
# 75%     33930.697500  105842.960000     132877.992500    2014.000000
# max    400184.250000  567595.430000     567595.430000    2014.000000

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay   Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25  400184.25  567595.43         567595.43
# 1  155966.02    245131.88  137811.38  382943.26  538909.28         538909.28
# 2  212739.13    106088.18   16452.60  122540.78  335279.91         335279.91
# 3   77916.00     56120.71  198306.90  254427.61  332343.61         332343.61
# 4  134401.60      9737.00  182234.59  191971.59  326373.19         326373.19
#
#    Year         Agency
# 0  2011  San Francisco
# 1  2011  San Francisco
# 2  2011  San Francisco
# 3  2011  San Francisco
# 4  2011  San Francisco

# %%
#printing missing values
print(df.isnull().sum())
# Out:
# Id                    0
# EmployeeName          0
# JobTitle              0
# BasePay             605
# OvertimePay           0
# OtherPay              0
# Benefits              0
# TotalPay              0
# TotalPayBenefits      0
# Year                  0
# Agency                0
# dtype: int64

# %%
#handling numerical missing values
df2 = df.fillna(df.mean())
print(df2.isnull().sum())
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
#there are no categorical fields with null data
#however there the field BasePay still has missing values
#hence we will handle them by dropping them

# %%
#now we don't have any more missing values...

# %%
# %matplotlib inline

# %%
#handling outliers
df.boxplot("TotalPay", figsize=(12, 6))

# %%
df.boxplot("BasePay", figsize=(12, 6))

# %%
df.boxplot("TotalPayBenefits", figsize=(12, 6))

# %%
df.boxplot("Benefits", figsize=(12, 6))

# %%
sns.FacetGrid(df, hue="Year", size=12) \
   .map(plt.scatter, "BasePay", "OvertimePay") \
   .add_legend()

# %%
#doing min-max normalisations on TotalPay and TotalPayBemefits
df3 = df
df3.TotalPay=(df3.TotalPay-df3.TotalPay.min())/(df3.TotalPay.max()-df3.TotalPay.min())
df3.TotalPayBenefits=(df3.TotalPayBenefits-df3.TotalPayBenefits.min())/(df3.TotalPayBenefits.max()-df3.TotalPayBenefits.min())

# %%
df3.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148650.000000  148045.000000  148650.000000  148650.000000
# mean    74325.500047   66325.448840    5066.059886    3648.767297
# std     42911.703176   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37163.250000   33588.200000       0.000000       0.000000
# 50%     74325.500000   65007.450000       0.000000     811.270000
# 75%    111487.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year
# count  148650.000000  148650.000000     148650.000000  148650.000000
# mean    20906.772746       0.132676          0.165982    2012.522603
# std     16955.512494       0.088904          0.110509       1.117526
# min       -33.890000       0.000000          0.000000    2011.000000
# 25%      1864.000000       0.064743          0.078653    2012.000000
# 50%     25101.310000       0.126793          0.163713    2013.000000
# 75%     33930.697500       0.187361          0.234940    2014.000000
# max    400184.250000       1.000000          1.000000    2014.000000

# %%
#data reduction
#removing useless atrribute - Id, Benefits and Agency
#Benefits is sum of OtherPay and OvertimePay and hence need not be considered again
#all the data is from the SAN FRANCISCO agency hence it also is redundant can be dropped

# %%
df5 = df3
df5 = df5.drop(columns=['Id', 'Agency','Benefits'])

# %%
df5
# Out:
#                   EmployeeName  \
# 0               NATHANIEL FORD
# 1                 GARY JIMENEZ
# 2               ALBERT PARDINI
# 3            CHRISTOPHER CHONG
# 4              PATRICK GARDNER
# 5               DAVID SULLIVAN
# 6                    ALSON LEE
# 7                DAVID KUSHNER
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
# 11            PATRICIA JACKSON
# 12           EDWARD HARRINGTON
# 13                 JOHN MARTIN
# 14              DAVID FRANKLIN
# 15             RICHARD CORRIEA
# 16                    AMY HART
# 17              SEBASTIAN WONG
# 18                  MARTY ROSS
# 19               ELLEN MOFFATT
# 20                  VENUS AZAR
# 21                JUDY MELINEK
# 22               GEORGE GARCIA
# 23               VICTOR WYRSCH
# 24             JOSEPH DRISCOLL
# 25                GREGORY SUHR
# 26                 JOHN HANLEY
# 27              RAYMOND GUZMAN
# 28              DENISE SCHMITT
# 29               MONICA FIELDS
# ...                        ...
# 148620         India C Sabater
# 148621          Kenneth Mackey
# 148622      Jacqueline Hubbard
# 148623         Deborah B Honig
# 148624      Lorraine Rosenthal
# 148625         Renato C Gurion
# 148626           Paulet Gaines
# 148627        Brett A Lundberg
# 148628          Mark W Mcclure
# 148629       Elizabeth Iniguez
# 148630            Randy J Keys
# 148631         Andre M Johnson
# 148632  Sharon D Owens-Webster
# 148633        Edward Ferdinand
# 148634          David M Turner
# 148635     James S Kibblewhite
# 148636           Andrew J Enzi
# 148637        Kadeshra D Green
# 148638    Lennard B Hutchinson
# 148639       Richard A Talbert
# 148640      Charlene D Mccully
# 148641   Raphael Marquis Goins
# 148642       Dominic C Marquez
# 148643              Kim Brewer
# 148644            Randy D Winn
# 148645        Carolyn A Wilson
# 148647          Joann Anderson
# 148648             Leon Walker
# 148649           Roy I Tillery
# 148653               Joe Lopez
#
#                                                 JobTitle    BasePay  \
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 5                              ASSISTANT DEPUTY CHIEF II  118602.00
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 7                         DEPUTY DIRECTOR OF INVESTMENTS  256576.96
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# 11                       CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 12                           EXECUTIVE CONTRACT EMPLOYEE  294580.02
# 13                                     DEPARTMENT HEAD V  271329.03
# 14                    BATTALION CHIEF, (FIRE DEPARTMENT)  174872.64
# 15                    COMMANDER III, (POLICE DEPARTMENT)  198778.01
# 16                                     DEPARTMENT HEAD V  268604.57
# 17                 CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 18                    BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 19                            ASSISTANT MEDICAL EXAMINER  257510.59
# 20                            ASSISTANT MEDICAL EXAMINER  257510.48
# 21                            ASSISTANT MEDICAL EXAMINER  257510.44
# 22                             CAPTAIN, FIRE SUPPRESSION  140546.88
# 23                    BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63
# 24                             CAPTAIN, FIRE SUPPRESSION  140546.86
# 25                                       CHIEF OF POLICE  256470.41
# 26                             CAPTAIN, FIRE SUPPRESSION   92080.80
# 27                    BATTALION CHIEF, (FIRE DEPARTMENT)  168692.59
# 28                  DEPUTY CHIEF III (POLICE DEPARTMENT)  261717.60
# 29          DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  246225.60
# ...                                                  ...        ...
# 148620                                 Recreation Leader      15.50
# 148621                                  Transit Operator       0.00
# 148622                                      Senior Clerk       0.00
# 148623                         Attorney (Civil/Criminal)       0.00
# 148624                                      Senior Clerk       0.00
# 148625                                  Registered Nurse       0.00
# 148626                                     Account Clerk       0.00
# 148627                                   General Laborer       0.00
# 148628                                   General Laborer       0.00
# 148629                                Transcriber Typist       0.00
# 148630                                         Carpenter       0.00
# 148631                       Communications Dispatcher 1       0.00
# 148632                        Protective Services Worker       0.00
# 148633                                   General Laborer       0.00
# 148634                               Transit Car Cleaner       0.00
# 148635                                   General Laborer       0.00
# 148636                               Arborist Technician       0.00
# 148637                            Transit Fare Inspector       0.00
# 148638                                       Electrician       0.00
# 148639                                         Custodian       0.00
# 148640                           Parking Control Officer       0.00
# 148641                                      Museum Guard       0.00
# 148642                                       Sign Worker       0.00
# 148643                           Parking Control Officer       0.00
# 148644                      Stationary Eng, Sewage Plant       0.00
# 148645                         Human Services Technician       0.00
# 148647                       Communications Dispatcher 2       0.00
# 148648                                         Custodian       0.00
# 148649                                         Custodian       0.00
# 148653                        Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay   OtherPay  TotalPay  TotalPayBenefits  Year
# 0              0.00  400184.25  1.000000          1.000000  2011
# 1         245131.88  137811.38  0.949515          0.949515  2011
# 2         106088.18   16452.60  0.591148          0.591148  2011
# 3          56120.71  198306.90  0.585980          0.585980  2011
# 4           9737.00  182234.59  0.575473          0.575473  2011
# 5           8601.00  189082.74  0.557720          0.557720  2011
# 6          89062.90  134426.14  0.557183          0.557183  2011
# 7              0.00   51322.50  0.542961          0.542961  2011
# 8          86362.68   40132.23  0.535091          0.535091  2011
# 9              0.00   17115.73  0.533243          0.533243  2011
# 10         71344.88   33149.90  0.528168          0.528168  2011
# 11         87082.62  110804.30  0.524850          0.524850  2011
# 12             0.00       0.00  0.519520          0.519520  2011
# 13             0.00   21342.59  0.516161          0.516161  2011
# 14         74050.30   37424.11  0.505031          0.505031  2011
# 15         73478.20   13957.65  0.504796          0.504796  2011
# 16             0.00   16115.86  0.502168          0.502168  2011
# 17        119397.26   18625.08  0.491342          0.491342  2011
# 18         69626.12   38115.47  0.487585          0.487585  2011
# 19           880.16   16159.50  0.484269          0.484269  2011
# 20             0.00   16679.79  0.483636          0.483636  2011
# 21           377.21   15883.56  0.482898          0.482898  2011
# 22         93200.58   39955.25  0.482778          0.482778  2011
# 23         77896.14   24083.86  0.477445          0.477445  2011
# 24         97868.77   31909.28  0.476833          0.476833  2011
# 25             0.00   11522.18  0.472728          0.472728  2011
# 26         40008.00  133695.76  0.468843          0.468843  2011
# 27         80706.88   16063.99  0.468277          0.468277  2011
# 28             0.00    2357.00  0.465833          0.465833  2011
# 29             0.00   15140.54  0.461067          0.461067  2011
# ...             ...        ...       ...               ...   ...
# 148620         0.00       0.00  0.001115          0.001115  2014
# 148621         0.00      15.35  0.001115          0.001115  2014
# 148622         0.00      13.77  0.001112          0.001112  2014
# 148623         0.00      13.35  0.001111          0.001112  2014
# 148624         0.00      12.89  0.001111          0.001111  2014
# 148625         0.00       6.00  0.001098          0.001101  2014
# 148626         0.00       0.00  0.001088          0.001088  2014
# 148627         0.00       0.00  0.001088          0.001088  2014
# 148628         0.00       0.00  0.001088          0.001088  2014
# 148629         0.00       0.00  0.001088          0.001088  2014
# 148630         0.00       0.00  0.001088          0.001088  2014
# 148631         0.00       0.00  0.001088          0.001088  2014
# 148632         0.00       0.00  0.001088          0.001088  2014
# 148633         0.00       0.00  0.001088          0.001088  2014
# 148634         0.00       0.00  0.001088          0.001088  2014
# 148635         0.00       0.00  0.001088          0.001088  2014
# 148636         0.00       0.00  0.001088          0.001088  2014
# 148637         0.00       0.00  0.001088          0.001088  2014
# 148638         0.00       0.00  0.001088          0.001088  2014
# 148639         0.00       0.00  0.001088          0.001088  2014
# 148640         0.00       0.00  0.001088          0.001088  2014
# 148641         0.00       0.00  0.001088          0.001088  2014
# 148642         0.00       0.00  0.001088          0.001088  2014
# 148643         0.00       0.00  0.001088          0.001088  2014
# 148644         0.00       0.00  0.001088          0.001088  2014
# 148645         0.00       0.00  0.001088          0.001088  2014
# 148647         0.00       0.00  0.001088          0.001088  2014
# 148648         0.00       0.00  0.001088          0.001088  2014
# 148649         0.00       0.00  0.001088          0.001088  2014
# 148653         0.00    -618.13  0.000000          0.000000  2014
#
# [148650 rows x 8 columns]

# %%
#data conversion
#using OvertimePay data to determine whether a person does overtime or not

# %%
bins = list()
for data in df5['OvertimePay']:
    if float(data) == 0:
        bins.append("No")
    else:
        bins.append("Yes")
#adding this data to the dataset...
s = pd.Series(bins)
df5['DoesOvertime'] = s.values

# %%
df5.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.00  400184.25  1.000000          1.000000  2011
# 1  155966.02    245131.88  137811.38  0.949515          0.949515  2011
# 2  212739.13    106088.18   16452.60  0.591148          0.591148  2011
# 3   77916.00     56120.71  198306.90  0.585980          0.585980  2011
# 4  134401.60      9737.00  182234.59  0.575473          0.575473  2011
#
#   DoesOvertime
# 0           No
# 1          Yes
# 2          Yes
# 3          Yes
# 4          Yes

# %%
#converting BasePay to categorical data

# %%
bins = list()
for data in df5['BasePay']:
    if (data) <= 50000:
        bins.append("very low")
    elif (data > 50000) & (data <= 200000):
        bins.append("low")
    elif (data > 200000) & (data <= 350000):
        bins.append("medium")
    elif (data > 350000) & (data <= 500000):
        bins.append("high")
    else:
        bins.append("very high")

# %%
df5.BasePay = bins

# %%
df5.head()
# Out:
#         EmployeeName                                        JobTitle BasePay  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     low
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)     low
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  medium
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC     low
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)     low
#
#    OvertimePay   OtherPay  TotalPay  TotalPayBenefits  Year DoesOvertime
# 0         0.00  400184.25  1.000000          1.000000  2011           No
# 1    245131.88  137811.38  0.949515          0.949515  2011          Yes
# 2    106088.18   16452.60  0.591148          0.591148  2011          Yes
# 3     56120.71  198306.90  0.585980          0.585980  2011          Yes
# 4      9737.00  182234.59  0.575473          0.575473  2011          Yes

# %%
#converting Otherpay to categorical data 
#categories : less, fair, extravagent

# %%
bins = list()
for data in df5['OtherPay']:
    if (data) <= 50000:
        bins.append("low")
    elif (data > 50000) & (data <= 300000):
        bins.append("fair")
    else:
        bins.append("extravagent")
        
df5.OtherPay = bins

# %%
df5.head()
# Out:
#         EmployeeName                                        JobTitle BasePay  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     low
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)     low
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  medium
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC     low
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)     low
#
#    OvertimePay     OtherPay  TotalPay  TotalPayBenefits  Year DoesOvertime
# 0         0.00  extravagent  1.000000          1.000000  2011           No
# 1    245131.88         fair  0.949515          0.949515  2011          Yes
# 2    106088.18          low  0.591148          0.591148  2011          Yes
# 3     56120.71         fair  0.585980          0.585980  2011          Yes
# 4      9737.00         fair  0.575473          0.575473  2011          Yes

# %%
#we will be looking for whether the person does a overtime or not

# %%
#hence we will be dropping the OvertimePay attribute

# %%
df6 = df5.drop(columns=['OvertimePay'])

# %%
df6.head()
# Out:
#         EmployeeName                                        JobTitle BasePay  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     low
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)     low
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  medium
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC     low
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)     low
#
#       OtherPay  TotalPay  TotalPayBenefits  Year DoesOvertime
# 0  extravagent  1.000000          1.000000  2011           No
# 1         fair  0.949515          0.949515  2011          Yes
# 2          low  0.591148          0.591148  2011          Yes
# 3         fair  0.585980          0.585980  2011          Yes
# 4         fair  0.575473          0.575473  2011          Yes

# %%
bins = list()
for data in df6['TotalPay']:
    if int(data) <= 0.2:
        bins.append("very low")
    elif (data > 0.2) & (data <= 0.4):
        bins.append("low")
    elif (data > 0.4) & (data <= 0.6):
        bins.append("medium")
    elif (data > 0.6) & (data <= 0.8):
        bins.append("high")
    else:
        bins.append("very high")
        
df6.TotalPay = bins

# %%
df6.head()
# Out:
#         EmployeeName                                        JobTitle BasePay  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     low
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)     low
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)  medium
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC     low
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)     low
#
#       OtherPay   TotalPay  TotalPayBenefits  Year DoesOvertime
# 0  extravagent  very high          1.000000  2011           No
# 1         fair   very low          0.949515  2011          Yes
# 2          low   very low          0.591148  2011          Yes
# 3         fair   very low          0.585980  2011          Yes
# 4         fair   very low          0.575473  2011          Yes

# %%
#we also do not need EmployeeName column

# %%
df6 = df6.drop(columns=['EmployeeName'])

# %%
df6.head()
# Out:
#                                          JobTitle BasePay     OtherPay  \
# 0  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     low  extravagent
# 1                 CAPTAIN III (POLICE DEPARTMENT)     low         fair
# 2                 CAPTAIN III (POLICE DEPARTMENT)  medium          low
# 3            WIRE ROPE CABLE MAINTENANCE MECHANIC     low         fair
# 4    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)     low         fair
#
#     TotalPay  TotalPayBenefits  Year DoesOvertime
# 0  very high          1.000000  2011           No
# 1   very low          0.949515  2011          Yes
# 2   very low          0.591148  2011          Yes
# 3   very low          0.585980  2011          Yes
# 4   very low          0.575473  2011          Yes
